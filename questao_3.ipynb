# %%
#!pip install pandas
#!pip install datasets evaluate transformers[sentencepiece] "requests==2.31.0" > /dev/null
#!pip install tensorflow
#!pip install torch torchvision
#!pip install torchaudio

# %%
import pandas as pd
from transformers import pipeline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/transformers/utils/import_utils.py:1560, in _LazyModule._get_module(self, module_name)
#    1559 try:
# -> 1560     return importlib.import_module("." + module_name, self.__name__)
#    1561 except Exception as e:
#
# File ~/miniconda3/envs/infnet-nn/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# ...

# %%
data = pd.read_csv('dataset/articles.csv')

data
# Out:
#                                                     title  \
# 0       Lula diz que está 'lascado', mas que ainda tem...
# 1       'Decidi ser escrava das mulheres que sofrem', ...
# 2       Três reportagens da Folha ganham Prêmio Petrob...
# 3       Filme 'Star Wars: Os Últimos Jedi' ganha trail...
# 4       CBSS inicia acordos com fintechs e quer 30% do...
# ...                                                   ...
# 167048  Em cenário de crise, tucano Beto Richa assume ...
# 167049  Filho supera senador Renan Calheiros e assume ...
# 167050  Hoje na TV: Tottenham x Chelsea, Campeonato In...
# 167051  Kim Jong-un diz estar aberto a se reunir com p...
# 167052  Heitor Maia Neto (1928 - 2014) - Pioneiro da a...
#
#                                                      text        date  \
# 0       Com a possibilidade de uma condenação impedir ...  2017-09-10
# 1       Para Oumou Sangaré, cantora e ativista malines...  2017-09-10
# ...

# %%
classifier = pipeline("ner", model="monilouise/ner_pt_br", grouped_entities=True)
classifier("Crie um ranking das organizações que mais apareceram na seção 'Mercado' no primeiro trimestre de 2015.")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 classifier = pipeline("ner", model="monilouise/ner_pt_br", grouped_entities=True)
#       2 classifier("Crie um ranking das organizações que mais apareceram na seção 'Mercado' no primeiro trimestre de 2015.")
#
# File ~/.local/lib/python3.10/site-packages/transformers/pipelines/__init__.py:895, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     893 if isinstance(model, str) or framework is None:
#     894     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 895     framework, model = infer_framework_load_model(
#     896         model,
#     897         model_classes=model_classes,
# ...
